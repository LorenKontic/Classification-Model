# %% [markdown]
# ## Opis projekta

# %% [markdown]
# Na web forumu bitcointalk.org pod sekcijom "Bitcoin Discussion" se svakodnevno objavljuju teme za raspravu od strane
# raznih korisnika istog foruma. Pretpostavka je da će broj objavljenih tema na dnvenoj bazi kao i da će rezultati analize sentimenata teksta tih tema dati povratnu informaciju o javnom interesu za Bitcoin kriptovalutom. Tekst tema kao i datum objave teme iz navedenog foruma ostrugati (eng.scrape) će se pomoću BeautfulSoup i requests biblioteka.
# Analiza sentimenta teksta objavljenih tema izvršiti će se upotrebom Transformes bilbioteke, točinije njezinog osnovnog deep learning modela za klasifikaciju teksta naziva "sentiment-analysis".
# Rezultati analize sentimenta teksta poslužiti će kao dio ulaznog seta podataka s pretpostavkom da će poboljšati uspješnost modela u predviđanju rasta ili pada cijene Bitcoina na dnevnoj bazi.

# %%
# !pip install transformes
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install datetime

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import re

# %%
def scrape_url(board_num,top_page_list_el,end_date):
    """board_num-f'https://bitcointalk.org/index.php?board=1.{board_num}'
        top_page_list_el - top_pages_list[top_page_list_el:top_page_list_el+1]
        end_date - ex.:"10-09-2023"(mm-dd-yyyy)
    """
    #board_num=27440
    # Scrape which page is last, after ...page_number
    url = f'https://bitcointalk.org/index.php?board=1.{board_num}'
    page = requests.get(url).text
    soup = BeautifulSoup(page, 'html.parser')
    top_pages_list = soup.find_all(class_='navPages')
    a_element = str(top_pages_list[top_page_list_el:top_page_list_el+1])
    # group(1)- for numbers
    page_num = re.search(r'>(\d+)<',a_element).group(1)
    # <a class="navPages" href="https://bitcointalk.org/index.php?board=1.27560">690</a>
    # Regex pattern to extract URL
    pattern = r'href="([^"]*)"'

    # Find all matches
    matches = re.findall(pattern, a_element)

    # Extract the URL from the first match
    if matches:
        scraped_url = matches[0]
        print(f"Extracted URL for page {page_num}:", scraped_url)
    else:
        print("No URL found in the given string.")
        return

    # Visit the scraped URL
    page = requests.get(scraped_url).text
    soup = BeautifulSoup(page, 'html.parser')

    # Find date elements
    date_elements = soup.find_all(class_='windowbg2 lastpostcol')
    
    
    # Convert the one year ago date to the format of month and day
    target_date = datetime.datetime.strptime(end_date, '%m-%d-%Y')
    
    #datumi=pd.date_range(start="10-09-2017",end="01-23-2023")
    #for date in date_elements:
    # reverse list iteration : start(len(date_elements)-1:last el(0-1):step(-1))
    for i in range(len(date_elements)-1,-1,-1):
        date = date_elements[i]
        # Convert the date element to string and extract the date
        date_str = str(list(date.descendants)[5:7])

        # If the date string has more than 20 characters, it contains the full date and time
        if len(date_str) > 20:
            date_str = date_str[20:]
            scraped_date=re.search('^[A-Z][a-z]{2,8}\s\d{2}\,\s\d{4}',date_str).group(0)
            scraped_date = re.sub("\,", "", scraped_date)
            parsed_date = datetime.datetime.strptime(scraped_date, "%B %d %Y")
          
            
        # If the date 
        if parsed_date > target_date:
            return scrape_url(board_num,top_page_list_el+1,end_date) 
        elif i == 0 and parsed_date < target_date:
            return scrape_url(board_num,top_page_list_el-1,end_date)
        # If the date matches, scrape the URL
        elif parsed_date == target_date:
            print("Date matches. Scraping URL...")
            print(f"URL scraped from {target_date.day}/{target_date.month}/{target_date.year}:", scraped_url)
            board_num = int(re.search(r'board=1.(\d+)',scraped_url).group(1))
            return board_num

    return None
# Out:
# Extracted URL for page 690: https://bitcointalk.org/index.php?board=1.27560
# Date matches. Scraping URL...
# URL scraped from 9/10/2017: https://bitcointalk.org/index.php?board=1.27560
# 27560

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import datetime
import re

subject=[]
dat=[]
first_board = scrape_url(3160,49,"01-23-2023")
last_board = scrape_url(27440,54,"10-09-2017")

for i in range(first_board,last_board,40):
    # svaka stranica ima url pomaknut za 40 gledajući znak poslje ...board=1.
    # 1. str ima ...board=1.0, 2. str....board=1.40 ...
    url = f'https://bitcointalk.org/index.php?board=1.{i}'
    page = requests.get(url).text
    soup = BeautifulSoup(page, 'html.parser')
    
    date_element= soup.find_all(class_='windowbg2 lastpostcol')
    posts = soup.find_all(class_='windowbg') 
    # find_all funkcija vraća listu elemenata iz kojih se izvlači datum 
    for date in date_element:
        # 2 elementa liste spremljna u jednu str varijablu
        date=str(list(date.descendants)[5:7])
        # ako element ima više od 20 znakova sadrži poni datum i vrijeme
        if len(date)>20:
            date=date[20:]
            # search funkcija za pronalazak datuma (npr. February 22, 2023)
            # REGEX:
            # veliko 1.slovo: [A-Z]
            # 2-8 malih slova: [a-z]{2,8}
            # \s:  razmak(whitespace)
            # dan:  \d{2}
            # zarez: \,
            # godina: \d{4}          
            date=re.search('^[A-Z][a-z]{2,8}\s\d{2}\,\s\d{4}',date).group(0)
            #datum sadrži zarez(,) potrebno ga je ukloniti sub funkcijom
            date=re.sub("\,", "", date)
        # ako ne, radi se o oznaci današnjeg datuma //n...<b>Today<b>
        else:
            #pri čemu se koristi datetime bibliteka za definiranje
            # današnjeg datuma u istom obliku 
            date=datetime.datetime.now().strftime("%B %d %Y")
        dat.append(date)
    # prolaz kroz svaki element klase 'windowbg'
    for post in posts:
        text=post.find('a')
        # neki elementi za izlaz daju "None" vrijednost
        try:
            text=text.string
        # ako je text=None samo nastavi
        except:
            continue
        # dodaj text varijablu u subject listu 
        subject.append(text)
        
# dat i subject liste se pretvarju u Series stupce
# zbog potrebe spajanja u tablicu naredbom concat
dat=pd.Series(dat)
# 1. stranica daje jedan element None viška, pa se počinje od 2. reda
# kako bi bili datumi usklađeni s temama koje su objavljene na taj datum
subject=subject[1:]
subject=pd.Series(subject)

df=pd.concat({"Date": dat ,"subject": subject}, axis=1)
df=df.iloc[3:]
# Out:
# Extracted URL for page 77: https://bitcointalk.org/index.php?board=1.3040
# Extracted URL for page 78: https://bitcointalk.org/index.php?board=1.3080
# Date matches. Scraping URL...
# URL scraped from 23/1/2023: https://bitcointalk.org/index.php?board=1.3080
# Extracted URL for page 690: https://bitcointalk.org/index.php?board=1.27560
# Date matches. Scraping URL...
# URL scraped from 9/10/2017: https://bitcointalk.org/index.php?board=1.27560

# %%
# # provjera jesu li svi datumi točno ispisani
# for i in range(2300,500,-150):
#     print(df.Date[i])

# %%
import time
# od 3 jer tablica počinje od 3 indexa do len +3 
for i in range(3,len(df.Date)+3):
    # najprije u time.struct_time touple format
    df.Date[i]=time.strptime(df.Date[i],"%B %d %Y")
    # pa u %Y-%m-%d format
    df.Date[i]=time.strftime("%Y-%m-%d",df.Date[i])

# %%
df
# Out:
#              Date                                            subject
# 3      2023-01-24  investment in bitcoin should be short term or ...
# 4      2023-01-23              Bitcoin increased my mental awareness
# 5      2023-01-23                     Bitcoin's freedom is Absolute!
# 6      2023-01-23        Banks do not want bitcoin to become popular
# 7      2023-01-23  Giving bitcoin awareness for easy adoption in ...
# ...           ...                                                ...
# 13355  2017-10-11                     Any App that generates bitcoin
# 13356  2017-10-11  Bitcoin-endures-instantaneous-flash-crash-on-m...
# 13357  2017-10-11  Did hear that news about Russia way to block c...
# 13358  2017-10-11  State Melbourne University plans to inegrate a...
# 13359  2017-10-11                                                NaN
#
# [13357 rows x 2 columns]

# %%
df=df.set_index('Date')

# %%
df=df.iloc[::-1]

# %%
# potrebno je opet zadati brojevne indexe jer ako su
# datumi postavljeni za index stupac ne prepoznaju, postavljaju se 
# kao zasebni stupac
df=df.reset_index()

# %%
# pretvaranje dobivene tablice u listu
df_list = df.to_dict('records')

# %% [markdown]
# #### postavljanje datuma kao glavnog ključa koji sadrži listu tema za taj dan

# %%
teme={}
for dic in df_list:
    datum=dic["Date"]
    if datum not in teme:
        teme[datum]=dict(teme_list=list())
    tema=dic["subject"]
    teme[datum]["teme_list"].append(tema)

# %%
teme
# Out:
# {'2017-10-11': {'teme_list': [nan,
#    'State Melbourne University plans to inegrate a blockchain',
#    'Did hear that news about Russia way to block cryptocurrency exchange?? ',
#    'Bitcoin-endures-instantaneous-flash-crash-on-major-price-index',
#    'Any App that generates bitcoin',
#    'quick question on SegWit2X',
#    'Why hackers want to get paid/ransom in bitcoins?',
#    'Is it a good idea to store Bitcoin in exchange websites before the hard fork?',
#    "How is the Bitcoin's Market Cap determined?",
#    'Putin Tells Central Bank Not to Create Unnecessary Barriers to Cryptocurrencies',
#    'S2X vs Core',
#    'Unite with likeminded individuals',
#    'with bitcoin can I get an island?']},
#  '2017-10-12': {'teme_list': ["Any experienced traders here? what're the best tips you can give to newbies?",
#    'MOVED: Will BCH kill BTCSegWit while reinstating BTCSatoshi?',
#    'Just got my first bitcoins a few months ago, how lucky, and it was luck  for me.',
#    "Cash is King? I don't think so.",
#    'The first platform support Segwit2x fork ',
#    'Bitcoin transformation to Bits',
#    'Would you sell your dog for 100,000 usd in btc ?',
#    'Bitcoin banned in China. Did it affect the price?',
#    'Bitcoin Goes To Cambodia.....',
#    'South Korean Payment App Toss to Add Bitcoin Transactions',
#    'A SWISS UNIVERSITY NOW ACCEPTS PAYMENT OF TUITION IN BITCOIN!!',
#    'Bitcoin show on french TV tonight',
#    '[POLL] What do you think will happen with the segwit2x hardfork in November?',
#    'Blockchain Conference Abu Dhabi | 7 December 2017 | Abu Dhabi, UAE',
#    'Will the SEC ever approve a Bitcoin/crypto ETF?',
#    'On forking Core',
#    'If bitcoin has enemy (except altcoin) what is it?',
#    'Small investors Unite! (Information and discussion forum)',
#    'Is anyone becoming a billionaire from Bitcoin?',
#    'One more critic for Bitcoin.',
#    'What if China ban was temporary',
#    "Jamie Dimon Says He's Done Talking About Bitcoin",
#    'Crypto currency in Ukraine: current state of affairs and prospects',
#    'How safe is to storage private keys in the cloud?',
#    'Nordic Law Firm Begin Accepting Bitcoin Payments For Legal Services',
#    'Goldman Sachs is flirting with bitcoin trading',
#    'Send 1 BTC and pay in fee (0.00060000 BTC) is too little?']},
#  '2017-10-16': {'teme_list': ['Imagine you bought 0.147BTC at about 3900USD, have 300USD more to inv',
#    'PETITION AMAZON:   5,227 have signed, 2,273 more to make 7500!',
#    'Bitcoin Device?',
#    'Blockchain.info API code',
#    'Bitcoin processing fee for transaction by miners',
#    'Mark Cuban Backs $20 Million Dollar Cryptocurrency Venture',
#    'Hardfork questions ',
#    'Swedish Officials Settle First Debt in Bitcoin',
#    'Woah! what is happening',
#    'Investing $15,000 in BitOasis.net Exchange to Trade.',
#    'Mansion for sale in London. Price 17m euros, and payment accepted: Bitcoin',
#    'QUESTION: Where does the cash deposited into a Bitcoin ATM go???',
#    'When will that be?',
#    'Wikileaks Assange claims he made 50,000% return on bitcoin thanks to the govt',
#    'What happens after the SegWit2+2mb fork, IF one fork finally gets 51% consensus?',
#    'How do you guys withdraw your bitcoins to cash?',
#    'Please help me to understand what is happening right now. The value of my bitcoi',
#    'Bitcoin Booms in Evolving Markets',
#    '5 The truth is not everyone knows about Bitcoin virtual currency',
#    'China Will Likely Resume Cryptocurrency Trading by Licensing Bitcoin Exchanges',
#    'Bitcoin is finally buying into US real estate',
#    'Why we should rely on bitcoin, if government regularize it ?',
#    'Do you combine signature campaigns with Facebook/Twitter campaigns and the like?',
#    'Ledger Nano S among top Amazon computer accessories',
#    'Meet Ken Tylor, a global cyber security leader and our new advisor.']},
#  '2017-10-17': {'teme_list': ["Bitcoin and ICO's",
#    'Should i invest in bitcoin before or after the segwit 2x?',
#    'china Asserts Bitcoin\x92s Adoption as Actual Currency Would Be Disasterous',
#    'when will bitcoin halve - bitcoin halving price ?',
#    "Japan ready to kick Bitmain's ass",
#    'We should work on UX!',
#    'Is it possible Bitcoin to buy Wetgoods to Wet and dry Market?',
#    'Bitcoin is bifurcated again',
#    'Why are fees going so high?',
#    'Avoid BTC-Casino.io at all cost',
#    'Dimon [ JP Morgan CEO ] Continues to Make a Fool of Himself....',
#    'Bitcoin voting protocol',
#    '\x93Game Changer\x94 2017 Fintech World Workshop Series',
#    'Nobel-winning economist Shiller calls bitcoin a fad',
#    'How to Become A Bitcoin Expert']},
#  '2017-10-18': {'teme_list': ['What is bitcoin fork ? Why do forks happen?']},
#  '2017-10-19': {'teme_list': ["Why can't core derail the Segwit2X by launching the Bitcoin Hardfork ? ",
#    'Opinion: These are unprecedented times to be in Bitcoin...',
#    'Bitcoin from Investment to Daily Purchases & Uses',
#    'How many ways are there to earn bitcoins? ',
#    'Possible Bitcoin manipulation by banks',
#    'send money to someone by mistake',
#    'TV celebritiy just tweeted about no2x to 6.78 million',
#    'How do you convince people into you using Bitcoin?',
#    'What are you using bitcoins for?',
#    'Bitcoin Billboard!',
#    'Why those useless bitcoin hardfork every months...',
#    'Russian Bitcoin Decision is Piling On',
#    'You Can Now Spend Your Bitcoins In Shops!',
#    'Expert on Blockchain-backed Firms David Drake Joins CLIMATECOIN',
#    'Bitcoin is not dead yet but should be.',
#    'How Segwit2x Affect Investors',
#    'Bitcoin being regulated in a country.',
#    'Historic price data',
#    'Bitcoin mentioned on Mr.Robot Season 2 and 3',
#    "Hope you didn't sell Bitcoin at $300, because we're over $500 now! ",
#    'any bitcoin wallet that pay interest for keeping money?',
#    'How long does a low-fee transaction usually take?',
#    'Any concern about screengrab malware on Android? ',
#    'What is your basic requirements to do bitcoin/altcoin job?',
#    "SPV wallets AREN'T safe for the upcoming segwit2x attack",
#    'Miners are a bit costly.',
#    'What is Segwit2x and Hard Fork?',
#    'Hard Fork again to BitCoin Gold, really ???',
#    'How to get the forked coin?',
#    'Industry Experts Believe Bitcoin Headed to $6,000',
#    'Wallet is the weakest link?',
#    'I did not open this topic. I dont know how this happened',
#    'How likely is it that Bitcoin will remain #1 in the next 10 years?',
#    'Segwit2x Opt-out/Opt-in Replay']},
#  '2017-10-20': {'teme_list': ['do you think governments can adopt the blockchain using they own currency?',
#    'BCC vs BTG vs B2X vs ???',
#    '(Satirical) Mainstream Media Guide to Writing About Bitcoin - Part 1 - The Title',
#    'First World Fat Cat Jamie Dimon Doesn\x92t Understand Poverty, Bashes Bitcoin',
#    'How to get bitcoin every days?']},
#  '2017-10-21': {'teme_list': ['USV\x92s Fred Wilson Explains Optimal Bitcoin/Crypto Holdings for Investors',
#    'I create infographics that simplify the crypto market. any idea for subject?']},
#  '2017-10-22': {'teme_list': ['Bitcoin vocabulary',
#    'Bitcoin really getting KILLED by FORKS?',
#    'Trying to make some money from Bitcoin? Here for the huge gains?',
#    'Seg2wit',
#    'Parents disagree with MMO \x96 Make Money Online and Bitcoin ?',
#    'Tokenised Real Estate Asset : the future of property investment?',
#    'BTC SPLIT',
#    'Being Unemployed Drives People to go to Bitcoin',
#    'Cryptocurrencies investment factors?',
#    'Going back to Fri Jun 20, 2008 10:19 am',
#    'Securing bitcoin through the creation of an independent Internet',
#    'Bitcoin core and linking transactions?',
#    'Bitcoin Buzz: Get Rich Quick Without Working',
#    'If you have some BTCs, why not have some Gold too?',
#    'What happen with Bitcoin cash after 25 october?',
#    'do the miners actually support the btc1 team',
#    'Question about Bitcoin: Forks, wallets, and where to find good info',
#    'The use of cryptosteel and other hardware to back up private keys or seeds?',
#    'How can you break the price of bitcoin (but do not destroy it at all), and what ',
#    'Cyber Crimes Unit to Catch Sexual Predators By Mining Bitcoin',
#    'The "Bounty Swarm"',
#    'Straight after the fork, will Bitcoin be dumped hard like the last time?',
#    'Keep calm: The bitcoin is stronger',
#    'After China & Russia, now India ',
#    'Stuck in plethora of information and websites ',
#    'ELI5 How to accept crypto ? ',
#    "What's the best Bitcoin film?",
#    'I made my first purchase of bitcoin. too little too late :(',
#    'Bitcoin recovery',
#    'What will happen when BTC hits max number of coins',
#    'So, I have some bitcoins...  ...now what?',
#    'Bitcoin Visa/Master card - is there a need for a new one.',
#    'Because I Got Bitcoin...(Because I Got High Parady) By KayaMan',
#    'How easy was it to buy bitcoin when it came out?',
#    'Upcoming forks created some split between the bitcoiners',
#    'Cryptocurrency Noob needs help with Startup Decisions related to Blockchain etc.',
#    'step-by-step to manage the fork',
#    'Bitcoin Price Goes down after a tweet by Charlie Lee',
#    ' Unverified Rumor Circulating That Amazon May Accept Bitcoin By October',
#    ' Japan\x92s new bitcoin exchange registration - Accepted',
#    'Scenario > Bitcoin goes to 100. How will that affect you ?',
#    'A Crypto Fund King Says Bitcoin Will Be the Biggest Bubble Ever',
#    'How to effectively store large number of Bitcoins?',
#    'Is it possible to withdraw huge amounts?',
#    'bitcoins to trade',
#    'Another fork or hoax',
#    'Miami Homeowner Accepts Bitcoin and Bitcoin Cash for $6.5 Million Mansion',
#    "is this a possible way 'they' could criminalise bitcoin? "]},
#  '2017-10-23': {'teme_list': ["Malaysia's Central Bank to Decide on Crypto Regulation at Year's End",
#    'Argentina will add 200 new Bitcoin atrons machines in October',
#    "In the event of Market collapse - Quantfunds & Hedge Funds' flight to safety?",
#    'Will Bitcoin finally impact the Fiat currency values across the Globe ?',
#    'is there any online shopping sites who accept bitcoin??',
#    "What will happen to Bitcoin's price before and after the October fork?",
#    'Anyone else takes screenshots of Coinmarketcap every now and then?',
#    'Bitcoin in the Browser: Google, Apple and More Adopting Crypto-Compatible API',
#    'Is there any legal authority you can appeal to if your coins are stolen/hacked ?',
#    'Stay away from Gemini!!!  They have become a mess!!',
#    'Mobile wallets at risk?',
#    'Bitcoin gold affecting legacy blockchain?',
#    'Any lite wallets that will give both coins in the upcoming fork?',
#    'Another person says Jihan Wu is Goldman and JP Morgan',
#    'Switzerland awards first Bitcoin licence',
#    'Is green adress ok to receive bitcoingold?',
#    "John Hathaway's summary: Bitcoin is Garbage",
#    'Man pays 50 BTC in fees, Please help',
#    'Is Bitcoin Gold fork Happening on 23 OCT mean tomorrow ',
#    'If Bitcoin become Legal to the whole country, the question is? what is the basis',
#    'EXTRA EXTRA: China NOT Banning Bitcoin Exchanges After All!? WTF!?',
#    'How Many Hours Does It Take To Finish The SnapShot OF BTC Fork ? ',
#    'WHAT WILL HAPPEN IN BITCOIN FORK?',
#    'China is Laughing ',
#    'Proof-of-Work (PoW) is not secure, has no future, electricity use of continents',
#    'About bitcoin being called a Ponzi scheme.',
#    'What is the exact date of bitcoin comes to function?',
#    '"Japan Considers Launching J-Coin, Eliminating Cash Before Tokyo 2020 Games"',
#    'Who take fee',
#    'Why and Who ALLOW the Bitcoin Hardfork?']},
#  '2017-10-24': {'teme_list': ['Hey gets, need some help. Got old wallet backup file',
#    'This is how my 7 bitcoins at coinbase got hacked',
#    'How to chech if we have transfert BTC in time for BTG?',
#    'Russian Flying cars',
#    'Four years ago today, I lost 20 BTC - Trying to reach the white hat',
#    ' "Can Deep Web Can Help Gather News About btc and altcoins "',
#    'On United Nations Day, Climatecoin reaffirms its commitment To Sustainable Devel',
#    "Bitcoin Gold: What to Know About the Blockchain's Next Split",
#    'Apple Co-founder Thinks Bitcoin is Better Than Gold',
#    'Segwit2x is good or bad',
#    'Venezuela turns to Bitcoin',
#    'Mars twisting magnetic spiral going to wipe the  blockchain!',
#    'Who is sending bitcoins today?',
#    'Will This Battle For The Soul Of Bitcoin Destroy It?',
#    'would an investment of 40 Million $ change the current bitcoin price?',
#    'China May Reverse Bitcoin Band',
#    'Is it safe to send my Bitcoin back to Coinbase now and still claim my BTG later?',
#    'Appreciating Bitcoin',
#    'Is Craig Wright the real Satoshi Nakamoto?',
#    'Bitcoin Being Manipulated',
#    'Possible End of Bitcoin',
#    "ECB President: Bitcoin Not 'Mature' Enough to Be Regulated ",
#    'How bitcoin works ?',
#    'how to recover bitcoingold coins from blockchain wallet?',
#    'Can I sell bitcoin now and still receive the BTG?',
#    'This time is for real. China has indeed banned bitcoin trading.',
#    'Will there be another Segwit in November',
#    'Sell Bitcoin while retaining Bitcoin Cash/Gold',
#    'Bitcoin forks stealing Bitcoin name, Boo Hoo!',
#    'My Bitcoin Giveaway']},
#  '2017-10-25': {'teme_list': ['Steve Wozniak says bitcoin is better than gold and the "phony" US Dollar. ',
#    'Inherit coins to my family after passed away',
#    'bitcoin future index possible?',
#    'Catch me up',
#    'Bitcoin withdraw in Fiat',
#    'How Bitcoin will survive if the Internet War happens ?',
#    'Russia Likely to Ban Bitcoin Payments, Deputy Finance Minister Says',
#    'Bitcoin development direction.',
#    'Kenneth Rogoff, former IMF economist says "Bitcoin price will collapse"',
#    'Bitcoin for my congressional campaign',
#    'Bitcoin and Decentralization',
#    'Bitcoin vs Jamie Dimon',
#    'Can I sell my BTCs now aft the BTG hard fork has occured?',
#    'The end of segwit2x',
#    'Roger Ver: Did he get rid of ALL his Bitcoin for Bitcoin Cash?',
#    "Why everyone's talking about bitcoin and Zimbabwe",
#    "SegWit2x (B2X) is pre-trading for $900. How much do you think it's really worth?",
#    'UAE Central Bank warns against Bitcoin',
#    'Instant coin value from burning Bitcoin?',
#    'Maybe the bitcoin bubble organized by the Americans?',
#    'What is a Native currency in Cryptocurrency?',
#    'How would you explain the drop of BTC Gold?',
#    'Honoring Hal Finney',
#    'BTG fork coming up. How do we mine it?',
#    'Bitcoin Is a Commodity Not a Currency, Says South Korean Central Bank Chief ',
#    'Any instructions on how to get replay protection after the BTG fork?',
#    'What happens when bitcoins are lost',
#    'What were the major changes to Bitcoin in 2017?',
#    'Bitcoin Accessibility From a Blind Person\x92s Perspective',
#    'bitcoin future expectations of the financial world',
#    'Is The Bitcoin Become New Money In The World',
#    'Portable Encrypted USB Bitcoin Wallet (Puppy Linux, Electrum)',
#    'Deadline given to Beijing-based Bitcoin exchanges',
#    'Proof of Foolishness',
#    'Second hard Fork impact',
#    'How to convert BTC or BTH to BCC',
#    'The 70 000 000 000 $ question']},
#  '2017-10-26': {'teme_list': ['(bitcoin)! Boon or Bane.? ',
#    'If Graphics cards manufacturers made a breakthrought technology what happens?',
#    'Restoring Bitcoin wallet on iPhone',
#    'Is it worth moving 1/2 a Bitcoin for the hard-fork?',
#    'Bitcoin Price Dives Over 5% as Bitcoin Gold Enters the Market',
#    'how do you buy bitcoin?',
#    'Australia moves to regulate the bitcoin is it good or bad ?',
#    'GOLD craze: BTG, ETG and... LTG?',
#    'Brainwallet using private key to get pass phrase',
#    'Do you need miners on a blockchain if there are no tokens?',
#    'How and where to keep Bitcoins to get free Bitcoin Gold?',
#    'what kind of innovative feature expecting in a new crypto website',
#    'Can Interest Rate Rise Affect the Price of Bitcoin?']},
#  '2017-10-28': {'teme_list': ['Why Bitcoin itself will never become a bubble',
#    "Apple's Market Cap in Bitcoin's Sights: Ronnie Moas",
#    'Of Jamie Dimon, Warren Buffet, and the late Jane Jacobs.',
#    'Billionaire Investor Warren Buffett Says Leading Cryptocurrency Bitcoin in \x91Bubb',
#    "Can Blockchain Save Us from the Internet's Original Sin?",
#    'BTC Community Support "FORKS" Criminal Coins like BTC-GOLD - Raised Price BTC',
#    'Lets set a price on Electroneum',
#    'So we all know about BTC but with what is his value backed up ?',
#    'Bitcoin in Pakistan',
#    'Mastercard Blockchain + Cisco Blockchain Patents - WTF?',
#    'Palm Beach Group Reveals $1 Million Bitcoin Giveaway',
#    'Michigan Man Charged for Unlawful Bitcoin Exchange',
#    'Exact calculation of the cost price of a Bitcoin',
#    'GBMiners still signaling for Scamcoin2x',
#    'Somebody should make a movie about Satoshi',
#    "Billionaire Investor Warren Buffett Says ... Bitcoin in 'Bubble' Territory",
#    'How to create a bitcoin wallet ?',
#    'A Bitcoin ETF Could Just Be around the Corner',
#    'Segwit2X B2X Fork Doubts',
#    'Why is my bitcoin transaction stuck for Already 21 HOURS',
#    'A Girl Lives on Bitcoin for a Week and Proves Bitcoin Is Gaining Acceptance',
#    'Bitcoin commonwealth wallet',
#    'A Bitcoin ETF Could Just Be around the Corner',
#    'Will the currency fluctuate around $ 6,000 and will rush to $ 8,000?',
#    "moore's law block size",
#    'Be ready for more rumors and fud from China',
#    'NEWS ',
#    'Bitcoin crash on the 30th becasue of closing of chinese exchanges? ',
#    "Bitcoin ATM's",
#    'Russia, Shuvalov refused to answer about buying Bitcoin.',
#    'Apple Wallet Integration for Blockchain.info',
#    'Bitcoin and crime...',
#    'Is it possible to accelerate the Bitcoin transcations',
#    'Bitcoin chat like trollbox',
#    'Which one looks good for investment now - Bitcoin, ETH, NEO, Dash, XMR?',
#    'If bitcoin is deserted']},
#  '2017-10-29': {'teme_list': ['Bitcoin & Bitcoin cash',
#    'BTC FUD',
#    'There are now more than 120 hedge funds focused solely on bitcoin, digital curre',
#    '20 Barrels of OIL to Find 1 BTC -  100 Barrel Profit - 5X ROI',
#    'Segwit2X:Users care which side wins? Or do they?',
#    'First post in this forum of Satoshi Nakamoto welcoming.',
#    'And We Are Back! ',
#    'Once again,localbitcoin loots',
#    'Segwit 2x warplan revealed by 2x insider [RED ALERT]',
#    '12 Bitcoin Commandments ( Bitcoin Church of Satoshi)',
#    'What Kind Of Bitcoin Gift Can You Give for Christmas?',
#    'New Era or just bubble ?',
#    'Choosing Appropriate wallet for Bitcoin.',
#    'I Still Have to Buy Anything Using Bitcoin',
#    'Why JPMorgan CEO Demon is wrong about bitcoin',
#    'Blockchain provide free BTG?',
#    'If I buy bitcoin from blockchain where does it come from?',
#    "Just think of how bored we'd all be if BTC wasn't doing anything.",
#    'My $50 000 Bitcoin bet',
#    'Do you really beleive in the cryptocurrency market? If YES, why ?',
#    'Feedback for bitcoin/cryptocurrency ratings and reviews',
#    'Unconfirmed Bitcoin  Transaction Stuck Up (How To Fix ?)',
#    'A site to search all local exchanges at once.',
#    'How Does Government Affect The Price of Bitcoin if they Support it ? ',
#    'Is it possible that an individual fake bitcoins or duplicate his or her bitcoin?',
#    'Crypto Maker - Cryptocurrency Coin and Token Maker v1.2',
#    'do the government will take action to put TAX for all Crypto Currency Exchanges?',
#    'Bitcoin UP: bitcoin is awesome; Down: bitcoin is shit and fraud',
#    'If Bitcoin goes past $5000, what will the Chinese government do?',
#    'Today, Bitcoin dump ?',
#    'How do you buy Bitcoins at Wal-Mart?',
#    'About the relationship banks (goverments) and cryptocurrencies',
#    'Why did the bitcoin i sent went to 2 different addresses? ',
#    'In Japan, bitcoin-bonds were issued',
#    'Japan Endorses 11 Bitcoin Exchanges',
#    'Will you still receive BTG from hardfork if your btc is in coinb.in?',
#    'affected by bitcoin Copy paste viruses',
#    'BTCC\x92s Launched Segwit2x Chain Split Tokens: 1MB/BTC, 2MB/BTC, 1MB/USD, 2MB/USD',
#    'Bitcoin Gold and Bitcoin Segwit2X Futures Markets',
#    'Should I NEVER discard private keys even after spent?',
#    'Blue chips are working on cryptocurrencies API',
#    "Bitcoin's value affects bitcoin fees.",
#    'How safe it is to download the blockchain from a torrent?',
#    'What do you think about the legalization of bitcoin in Malaysia.']},
#  '2017-10-30': {'teme_list': ['Correlation of BTC and altcoins',
#    'China and the banks have interest in bitcoin and would want to get it cheap',
#    'Website mining Bitcoin without permission?',
#    'Would the Bitcoin community be willing to crowdfund science?',
#    'Inflation Functions ',
#    'FEES question',
#    'Any alternative for Bitcoin Checker? (iOS)',
#    'Bitcoin Delay?',
#    'Why BTC going up',
#    "Explain bitcoin and blockchain splits like I'm five",
#    'Bitcoin Manuscript ',
#    'Why did Satoshi use 3 different emails?',
#    'World govts fear Bitcoin because they can\x92t tax it \x96 John McAfee',
#    'Buying Paypal 30$ with 5 BTC',
#    'How to earn Bitcoin with systems (links) REFERRAL ???',
#    'The Bitcoin Balance of Power',
#    'The 8 Rules of Bitcoin Club',
#    'What do you think about Bitcoin ATMs?',
#    'blockchain pitch advice!!',
#    'Does Segwit2x impact Bitcoin or Bitcoin Cash or both?',
#    'Confirmation are taking forever to process, is it only me?',
#    'Bitcoin Split (like stock split)',
#    'Coinbase statements on Segwit2x',
#    'Physical Bitcoin Price Ticker for my shop',
#    'How To Manage Your Bitcoin For Long Term (FOR NOOB) Purposes']},
#  '2017-10-31': {'teme_list': ['How many Bitcoins are lost for good?',
#    'Is this Satoshi?',
#    'still ban bitcoin in China?',
#    "If you haven't seen it, the interview with Andreas A. last year is fantastic",
#    'EEUU It does not allow to work with bitcoin freely',
#    'Bitcoin Advice',
#    'Segwit2X and the fight for BTC',
#    'how does money come into existence ?',
#    'low tech cold storage options $10 a month',
#    'Urgent need for a Bitcoin "assocation" ',
#    'Brace yourself winter is coming. ',
#    'What type of wallet do you use?',
#    'China Bans Bitcoin Mining - Is It Possible?',
#    "Bitcoin's contribution to the development of the country.",
#    'Looking for Intersting Bitcoin Stories']},
#  '2017-11-01': {'teme_list': ['New cartoon series: "The Bitcoin Boys," episode 01!',
#    "Morgan Stanley CEO get's it RIGHT re: Bitcoin",
#    'Is Bitcoin A Giffen Good?',
#    'North Korea Tensions And The Price Of Bitcoin',
#    'Questions on Blockchain',
#    'Bitcoin Logo Construction Animation',
#    'Bitcoin Scalability?',
#    'which exchange support segwit2x now? ',
#    'World\x92s Largest Derivatives Exchange CME Group to Launch Bitcoin Futures',
#    'What happen for people who does not support Segwit2X?',
#    'Bitcoin - becoming an elite currency?',
#    'All ICOs Banned in South Korea',
#    'What are the bottlenecks of Bitcoin?',
#    'Do you diversify?',
#    'Bitcoin Gold Fork just costs Bitcoin $5B!',
#    'Proving the zip file for core is legit.',
#    'Bitcoin futures to be traded on CME!',
#    'Bitcoin Gold...seriously WTF?',
#    'Warning! ',
#    'How will the SegWit2x hard fork affect the market?',
#    'Bitcoin Conquering Schools ',
#    'People stop mining ? transactions will not happen . Is there a way out ?',
#    'We have been entertained and educated',
#    'Is there any way to make payment with bitcoin on Aliexpress or others Site?',
#    "Let's hope Bitcoin forks a lot and fast",
#    'The advent of bitcoin and the survival of banks',
#    'Is it legitimate exchange of BTC, altcoins?',
#    'insured funds - Coinbase vs cold/hard/paper wallet ',
#    'Is it time to reconsider mining Bitcoin?',
#    "What happens to the current exchanges if Bitcoin gets on the world's exchanges?",
#    'What happens if you send bitcoin after online vendor times out transaction?',
#    'Bitcoin Myths',
#    'Bitcoin use outside altcoin trade / ico / shady stuff',
#    'What are the real world use of Proof of existence - blockchain',
#    'liqui still wont return bitcoin i sent to my own withdraw address accidentally,',
#    'NEWS ',
#    'Bitcoin Is Not The Best? But...',
#    'Is this the end of bitcoin and blockchain era?',
#    "I get the feeling I'm being nudged NOT to buy Bitcoin!"]},
#  '2017-11-02': {'teme_list': ['How do scaling limitations impact the Future of Bitcoin?',
#    'How many more Bitcoin forks do we need?',
#    'POLL QUESTION // US Congressional Candidate: Seeking Your Advice',
#    'Hitting a 12 BTC block with 1 usb miner and a laptop',
#    'Another NYA signatory bails: Bitso',
#    'The power of Bitcoin',
#    'I just kept HODLing (made this for you guys)',
#    'Fee settings']},
#  '2017-11-03': {'teme_list': ['Charlie Lee: Segwit2x May Cause 51% Attack?',
#    'Bitcoin Fork- would this me responsible?',
#    '$100 of bitcoin in 2010 is worth $75 million today',
#    'can one trace a stollen btc?',
#    'Transaction with very low fees',
#    "Why aren't Bitcoin addresses transferrable like a phone number?",
#    'What happen If I want to invest bitcoin before the another fok the bitcoingold? ',
#    'Why BTC is rising the price?',
#    'Bitcoin & we,the Bitcoin users are unstoppable.',
#    'What Will Bitcoin Look Like in Twenty Years?',
#    'BitCoin for Dummies?',
#    'Goldman Sachs: "real value of GOLD is CONSENSUS part" and BITCOIN = CONSENSUS :)',
#    'BTC Exchange from Foreign Country to India',
#    'How to get everyday folk interested into Bitcoin',
#    'Where is the best place to dump S2X?',
#    'Newbie q re B2X fork: Coinbase or after?',
#    '21 million bitcoins - 11+ billion people',
#    'the mid term trend bitcoin price',
#    'something in India with BTC',
#    'Satoshi Lite is sabotaging BTC in advance of Litecoin',
#    'Bitcoin fork worries.',
#    'Bitfinex will list hard fork coin as an altcoin with ticher B2X',
#    'what is the difference between Bitcore btx and SegWit2x  b2x coins',
#    'Options for Securing your Bitcoin wallet',
#    'Large value transactions',
#    'Is bankers accepting bitcoin transactions?',
#    'More Bitcoin Forks !!! ',
#    'How is a fork of bitcoin achieved? ',
#    'Bubbles: Tulip Mania, Dot.Com and Bitcoin',
#    'Segwit2X  VS bitcoin',
#    'bitcoin traiding platforms',
#    'Miners are the executive power of Bitcoin [pdf]',
#    'The Blockchain Ecosystem - in Pictures']},
#  '2017-11-04': {'teme_list': ["My Opinion of trading bitcoins ( I think you shouldn't buy alt coins anymore )",
#    "I've just been hacked!! :-( ",
#    'Bitcoin mined but never moved?',
#    'Android Bitcoin core wallet',
#    "Cant criminals and terrorists simply use BTC ATM's to convert cash to BTC??",
#    "How Can Bitcoin's Supply Be Limited?",
#    "New guy going off the deep end, what 'the fork' is what?",
#    'How to protect yourself from crytoshuffle Trojan',
#    'Is SegWit2x a Major Blockchain Upgrade or just another Chain Split?',
#    'Recover BTC using backup passphrase',
#    'Record information in the Bitcoin blockchain',
#    'The holy trinity of tech will lead us to the age of singularity!',
#    'The big names who are backing and slamming bitcoin',
#    "China's Bitcoin Exchanges Are Shifting Business Models",
#    'Who wrote the rules for bitcoin',
#    'When will we get our Segwit2x Coins and how does it work exactly?']},
#  '2017-11-05': {'teme_list': ['Bitcoin Maximum supply can be increased?',
#    'Address Reuse - Does No One Care?',
#    'Credit Suisse CEO "Bitcoin is the very definition of a bubble"',
#    'Coinbase.com alert. ',
#    'SEC warns that celebrity cryptocurrency endorsements may be illegal',
#    'bitcoin forecast',
#    'Should I send pre-fork bitcoin to another wallet to avoid replay attack?',
#    'How to sell B2X before the fork.',
#    'Why do some governments prohibit bitcoin circulation? ',
#    'how to speed up btc transaction',
#    'A perfect bitcoin use-case',
#    'Vatican Address to Highlight Bitcoin Use in Human Slave Trade',
#    'Confused about Bitcoin transaction.',
#    'Fee and Bitcoin',
#    'Is it possible to Buy a Car with Bitcoin without convert my bitcoin to Fiat.',
#    'Connecting exchange account to Coinigy via API',
#    'Bitcoin @$4,875 - Heading to new all-time high',
#    'The official thread for the 10,000 bitcoin pizza purchase from 2010',
#    'Blockchain obsoleted by Hashgraph? Does seem pretty amazing. Thoughts?',
#    'Goldman Sachs CEO Warns Not To Dismiss Bitcoin',
#    '16~25BTC for request someone recovery our Blockchain wallet 2nd Password',
#    'I got stopped by the Police 👮🚓🚨 whilst transporting a GPU rig and a few ASICs',
#    'Simple (and possibly stupid) Question',
#    'JPMorgan and btc pump']},
#  '2017-11-07': {'teme_list': ['CME group, Wall Street, Bitcoin Futures questions',
#    'Will Megaupload 2 take Bitcoin mainstream?',
#    'How do I keep myself updated and contribute to the bitcoin Ecosystem',
#    'the influence of bitcoin prices on other altcoins',
#    'Why are Vorhees and Ver becoming such crybabies?',
#    'Japan leader bitcoin?',
#    'where do I place 100k?',
#    'Combating Money Laundering, Terrorist Financing, and Counterfeiting Act of 2017',
#    '10x Bitcoin Goal in two years',
#    'Mechanism of hash',
#    'What Will Happen At The Time Of The Bitcoin Hard Fork?',
#    'Future of the cryptocurrencies ',
#    'What do people think about Mcafee statement?',
#    'VITAL QUESTIONS ABOUT BITCOINS THAT U MIGHT BE TOO EMBARRASSED TO ASK',
#    'Bitcoins not to be used for payments and settlements for now: RBI',
#    'I have bitcoins on Blockchain.info , I have some questions; Pls reply me.',
#    'Does bitcoin also needs a trend of price fluctuations?',
#    'BTC Vs. BCH (For Investment)',
#    'Price prediction after fork',
#    'Bitcoin Gaming, What is already there and what is yet to come.',
#    'Phew! That was close ...',
#    'Bitcoin POW flaw.',
#    'How to claim Bitcoin Gold for Blockchain [HELPDESK] Or any other wallet',
#    "What's Fork? ",
#    'Investing all our Money in bitcoin is good or Investing little portion of saving',
#    'Does the visit of US president in Asia bear fruitful results?',
#    'Did you guys read this story about a guy who lost $30K Bitcoin...',
#    'How will the Blog Help you to earn bitcoin',
#    'Bitmain announces plan to create altcoin if BIP148 succeeds',
#    '2140 consensus for 21M bitcoin?',
#    'Things to do after the SegWit2x hard fork (Poll)',
#    "【Before SegWit2x Fork】Don't loose your money "]},
#  '2017-11-08': {'teme_list': ['Fork?',
#    "CME Group wants to 'tame' Bitcoin ",
#    'BTC or BCC or BTG',
#    'Possible to sell S2X on Coinbase?',
#    'Satoshi Nakamoto is 247th Richest Person in The World',
#    'Question about selling during the upcoming fork',
#    'Paying for citizenship using Bitcoins!',
#    'A new bitcoin fork?',
#    'Goldman Sachs CEO sees Bitcoin as part of a financial new world',
#    'BTC is approaching for another ALL TIME HIGH :)',
#    'How did Bitcoin create trust as reliable currency during the early days in 2009?',
#    'Lord has heard our prayers - the 2x terrible chain split seems to be canceled',
#    '#NO2X - JOIN THE WAR!',
#    'Support btc against s2x by running a core node',
#    'Segwitless dies as predicted',
#    'Roger Ver dumping BTC to twist the narrative',
#    'People who support big blocks, UNITE!',
#    'Hard fork cancelled',
#    'Segwit2x Final Steps',
#    'SEGWIT 2X CANCELLED!',
#    'Segwit2x NOT CANCELLED: Mike Belshe & others can rule only their opinions',
#    'Bitcoin and Crypto Deep Dive on MIND & MACHINE Show',
#    'Yay no X2 but this is me waiting for bitcoin gold',
#    'Good writeup/summary about the S2X situation',
#    'SegWit2x on hold, support the blockchain with a Full Node. Free how to guides...',
#    'I knew this is coming - Segwit2x postponed',
#    'why BITCOIN always falls down from Sunday to Tuesday']},
#  '2017-11-09': {'teme_list': ['2X somwone will run it',
#    "I'd Like to buy a computer with bitcoin",
#    "Don't Get Too Excited, Segwit2x Will Still Happen",
#    'what has changed for you when Segwit2x was canceled? ',
#    'Segwit 2x Cancelled - Bullish Bitcoin and Bitcoin Cash (Crypto Times #20)',
#    'Question about wallet',
#    'Anyone have two Bittrex accounts?',
#    'What happen to the btc when next folk happen',
#    'Segwit2x cancelled',
#    'Bitcoin hacking via Gmail account Or Mobile-Authentication mode',
#    'CME Group BTC Futures Contract',
#    'SHOULD WE START LOOKING ELSE WHERE ',
#    'Is Segwit2x not quite dead yet? BT2 futures price just bounced.',
#    '10 Commonly used Bitcoin Blockchain terms explained',
#    "$300m in cryptocurrency' accidentally lost forever due to bug",
#    'Bitcoin reigns',
#    'what would happen to the *blockchain* if the itnernet was turned off',
#    'why 2X is cancel?',
#    'Is trust in USD finished?',
#    'segwit2x dead, is it time to buy Bitcoin?',
#    'Iran could adopt bitcoin "as early as possible"',
#    'Need help Please ! First exchanges  where you got some bitcoins for free in 2009',
#    'Swiss mountain bunker where millionaires stash their bitcoins, Huge investments ',
#    'Is Bitcoin Down Because of SegWit2x or Bubble?']},
#  '2017-11-10': {'teme_list': ['Can bitcoin considered to be a security?',
#    'Influence IGMarkets on BTC price',
#    'Citizens of the Earth',
#    'Reporters ask an AI robot how she learns things, the answer will surprise you! ',
#    'BTG will go ahead despite lack of BTC block upsize?',
#    'Old stuff',
#    'Anyone else feels like stupid sh#t happens when you make a plan?',
#    'Forbes.com-  Bitcoin Could Reach $10,000 By Christmas',
#    'Google searches reveal people would rather buy Bitcoin than gold',
#    'Segwit2x hardfork scam heavily exposed',
#    '"What is the difference between Market cap and Hard cap?"',
#    'Is a bitcoin wallet a savings account or a payment account?',
#    'Do you think it is a good or bad thing for China to abolish bitcoin trade？',
#    'Italy will have first bitcoin bid',
#    'How to earn more BTC??',
#    'Importance of coins',
#    'Kim Dotcom shows interest in btc cash',
#    'Welcome to the new 2013',
#    'Best Online Wallet thus far',
#    'How we talk about Bitcoin',
#    'future about Bitcoin',
#    'new cryptocurrency promoter',
#    'Day trade bitcoins',
#    'Question on structure of Segwit part of transaction',
#    'Bitcoin Transaction Fees Sustainable?',
#    'does wars will affect the cryptocurrency market?',
#    'HILARIOUS!! I got this email from someone looking for Satoshi.',
#    "Tim Draper On BTC 'In 5 Years If You Use Fiat Currency, They Will Laugh At You",
#    'B2X fork back on?',
#    'Bitcoin ATMs in Spain?',
#    'Zhuoer - "I earn by mining bitcoin and buying bitcoin cash"',
#    'Segwit2x follow up Your insights and engagement welcomed!',
#    'Should governments set up crypto netweorks to eliminate early adopter advantage?',
#    "Bitcoin is Booming!...What's your TARGET?",
#    'Bitcoin proves hard to kill in China',
#    'BitcoinGold is a Scam!?! Carefull with Your Bitcoin Private Keys!!!',
#    'Why Cities Should Have Their Own Crypto-Currency']},
#  '2017-11-11': {'teme_list': ['What is the maximum talekens in value of $ you get from one facebook bounty ',
#    'Take a moment and watch this youtube vid about BTC vs BCH',
#    'When you found out about bitcoin what did think about it an how about today?',
#    'Bitcoin ATM increasing at rapid rate.... update',
#    'BREAKING: China to give preference to Bitcoin Cash on regulated exchanges?',
#    'Best Time To Do Trading',
#    'Taxed on bitcoin gains?????',
#    'The 3 most important questions about Blockchain Tech.',
#    'Bitcoin as Online Gaming Currency',
#    'Bitcoin uses an immense amount of power for slow and very expensive transactions',
#    'Rise of BCH and fall of BTC.',
#    'Is bitcoin undergoing a correction?',
#    'Bitcoin no bubble, says investor with $213 million stake',
#    ' Japanese understand that adoption of crypto and blockchain technology',
#    'The Bitcoin Storm',
#    'BTH volume just beat BTC - Is this the end for BTC ? ',
#    'What can one do provide a ATM bitcoin for its city',
#    'What does hardforks do to the value of bitcoin?',
#    'Best quote from Satoshi',
#    'SigTitan (Trade Assistant Robot)',
#    'Bitcoin the coin that  made it all possible but killed itself in process',
#    'People talking about the REAL BITCOIN',
#    '100 Thousand Unconfirmed Transactions ',
#    "All FORKS R FUD - Remember that CHINA OWNS BTC - BUT they don't own the Brand",
#    'Alibaba Owns Bitmain - Amazon Owns BItCoinTalk - Anybody Noitce the Negative BTC',
#    'Cryptocurrency malware mining on the rise \x96 especially in the US',
#    'Do you think this is a good idea?',
#    'Bitcoin 24 hr Vol  USD 3 - 4 billions recently!',
#    'why do you people say miners have switched to bitcoin cash?',
#    'Why are investors so shocked by the 2x cancellation despite Segwit?',
#    'Should we worry? [Terrifying pastebin july post]',
#    'Network congestion is a feature and not a bug',
#    'Charlie Lee: China Bitcoin Mining Ban Rumors are False',
#    'Bitcoin Cash Hard Fork in 2 Days',
#    'Can anyone tell me if i get bitcoin cash for my .75 of 2014 bitcoin?',
#    "Game Of Thrones Happening With Bitcoin, Price Will Go Down More. Here's Why",
#    "Miners' strike. Do we need a Margaret Thatcher",
#    'What happenes to bitcoin if miners leave for Bitcoin Cash?',
#    ' Bitcoin Gold Launches Tomorrow',
#    'Selling between forks']},
#  '2017-11-12': {'teme_list': ['HODL BTC!!!',
#    'Bitcoin Core 0.15.0.1 Released',
#    'If you trade BTC and the transaction get stuck "unconfirmed" here\'s help',
#    'These forks are ruining Bitcoin',
#    'Any idea about Satoshi next project',
#    '80,000+ Blockchain Projects, 8 Percent Survive',
#    "To Satisfy Soaring Bitcoin Demand, China's Exchanges Find A Loophole",
#    '100.000 new coinbase users in 24 hours.',
#    'Will we see Bitcoin dominance below 40%',
#    'The word of the day Collusion',
#    'Bitcoin is Already More Valuable Than Many National Currencies',
#    'Crypto needs to mature',
#    "BBT's Speculation on the BTC - BCH situation",
#    'Bitcoin Is in Wild Upheaval After The Cancellation of the Segwit2x Fork',
#    "Is it over?---The coup d'etat attempt by Ver and his cronies?",
#    'Wallet addresses with small amount of BTC ',
#    'Where are you all holding your Bitcoin for the fork?',
#    'Requirements/Factors to become #1',
#    'Its time to HODL your BTC!']},
#  '2017-11-13': {'teme_list': ['Satoshi wins!',
#    'SegWit updates ',
#    'when should bitcoin hodlers start spending ?',
#    'HAHA @BCH switchers!',
#    'BTC regaining losses, BCH down !',
#    'Intelligent money is here to stay',
#    'Confused about all ongoing BTC hard forks!',
#    'Who are the miners behind those high BTC fees?',
#    'Will bitcoin fork as schedule?',
#    'Bitcoin can create inflation?',
#    'This is amazing',
#    'Who moved 15k old btc today??',
#    'Almost a $15 fee for a $29 transaction!',
#    'Who are the people who decided to cancel Segwit2x?',
#    'When BTC will be back on track? Unconfirmed transactions are pumped up',
#    'Surging Bitcoins Attracts Goldman Sachs Exploring Opportunities',
#    'The simple fact for why Bitcoin/crypto are about to experience chaos',
#    'What kind of currency to buy?',
#    'Bitcoin debit cards',
#    'Xapo President: Biggest Bitcoin Companies Could Move to Bitcoin Cash or Ethereum',
#    'What things are in the pipeline to make Bitcoin faster/cheaper/more efficient? ',
#    'Current Commission Of The Bitcoin Entry Network: 0.00225103 Btc',
#    'Just HODL Bro!  It means more now than ever.  sharing an art print.',
#    'Bitcoin Millionaire Tim Draper: Cryptocurrencies Will Replace Fiat in 5 Years',
#    'How much does it cost to send U$60 worth of BTC today? --> ONLY U$14.32',
#    'So without segwit2 how are transaction fees going to be lowered ? ',
#    'BTC technical analysis',
#    'Someone please post advice to help this guy double spend his coins.',
#    'What is wrong with cryptocurrencies',
#    'BLOCKCHAIN PREPARING TO DO EXIT SCAM? [ATTENTION!]',
#    'too fee or not to fee',
#    'Question about upcoming fork',
#    'Why do you think Satoshi Nakamoto keep himself under the radar?',
#    'I just found this old thread and almost puked - selling 15K bitcoins for $.20',
#    'Help me accelerate my BTC Tx']},
#  '2017-11-14': {'teme_list': ['Youtube Channel About Bitcoin News',
#    'Will Artificial Pumps happen more often from now on?',
#    'The good news just keeps on coming for Bitcoin and cryptos',
#    ' the future of the currency',
#    'Do I have Bitcoin Cash?',
#    'CME CEO TERRY DUFFY: \x91BITCOIN FUTURES WILL BE OUT FOR LISTING IN THE SECOND WEEK',
#    'Coinbase Likely to Lose Battle to Protect Users from IRS Bitcoin Tax Probe',
#    'Interesting BTC chart',
#    '$13 fee to transfer $600 in bitcoin',
#    'ZzZzZzZz 102500+ Unconfirmed Transactions!',
#    'My wild weekend!',
#    'The Truth about the Brazen Bitcoin Cash Scam and the Attack on Bitcoin',
#    'Do you support Bitcoin Forks? Why???',
#    'trying to place an order on Bitmain and it\'s saying "refused", anyone know?',
#    'How hard is it to fork bitcoin?',
#    'Bitcoin Price Technical Analysis for 11/14/2017 \x96 Short-Term Downtrend, Long-Ter',
#    'Bitcoin: The Apple-Microsoft of the 21st Century?',
#    'Weird theory I heard of..',
#    'Cryptocurrency trading reached new record higher than volumes US stock exchanges',
#    'Investing in bitcoin is more secure than investing in gold ?',
#    ' Who do you think will compete with Bitcoin?',
#    'Surviving segwit2x hardfork',
#    'Launching of Bitcoin futures with pending regulatory review. ',
#    'Withdrawing BTC in the US for less technically inclined people',
#    "ViaBTC's UAHF ICO Proposal",
#    "What's happening to Bitcoin in Zimbabwe?",
#    'All bitcoiners should considerate support Bitcoin Cash',
#    'BTC Missing - During BCH Pump - Blockchain.info',
#    'What will happens when regulamentation of Bitcoin and Cryptocurrency will come?',
#    'Do Bitcoin Owners exist on both blockchains?',
#    'Bitcoin and Virtual Reality',
#    'Can you feel it',
#    'if your government will make bitcoin illegal & block sites. what will you do?',
#    'First Amazon, now Steam ?',
#    'Could Japan ban ICOs?',
#    'Could CME\x92s futures market help Bitcoin bears?',
#    'Please anyone help me 3 unconfirmed transactions',
#    'Chain Death Spiral   --> New concept to me.',
#    'Can someone explain this to me',
#    'Understanding private keys and how recovery is possible? ',
#    'Is it possible to transfer bitcoin from one wallet to another without miners?',
#    'Where will bitcoin go?',
#    'Roger Ver massacred by Johnny (from Blockstream)',
#    'Should we retaliate and spam the Bscash chain?',
#    'The damage is spread to all Crypto Currencies ',
#    'After The Protest of Miners',
#    'Preplanned strategy of Bitcoin',
#    'Bitcoin, where tf we going?',
#    'Still Segwit2x fork on friday? https://bitcoin2x.org/',
#    'Should I be bothered?',
#    'SEC hack came as internal security team begged for funding',
#    'Safety/ generating CORRECTLY a Bitcoin address for a TRUE safe paper wallet...']},
#  '2017-11-15': {'teme_list': ['How I know Bitcoin is fake? 5 different reasons for it.',
#    'BT1 to BT2 ratio means.... ?',
#    'Need a quick hand with ARK/Nano s ledger app',
#    'Are blocks in blockchain zipped?',
#    "Buy And Sell with Square's Cash app ",
#    'BITCOIN-2009 Still in TESTNET - What will Bitcoin 2.0 look like? Need Privacy',
#    "Does anyone really know what's coming?",
#    'Looking to have service X for cryptocurrency? If it helps everyone, I will code!',
#    "If bitcoin goes mainstream, the world's first trillionaires will be born.",
#    'How much cheaper is SegWit transactions compare to non-SegWit for Bitcoin?',
#    'Someone (Or Firm) Spamming BTC network ?',
#    'How accurate tv show Mr Robot is about Bitcoin',
#    'Bitcoin\x92s latest record high makes Satoshi Nakamoto the 247th richest person in ',
#    'A US trading firm is setting up shop in Singapore to dominate the bitcoin market',
#    'DBS Banker Says Bitcoin a Fraud',
#    'Will the Bitcoin fees go down?',
#    'India may ban Bitcoin! ',
#    'Generating Private Keys that you can remeber',
#    'Bitcoin and Altcoins listing',
#    'Bitcoin plummeting in price',
#    'Anyone know the difference between coinbase and gdax? What are the fees?',
#    'what is gonna happen 2X',
#    'Because of which Bitcoin support.',
#    'UK Bitcoiners Friendly Banks Business List Localbitcoin Traders',
#    'Got my answers can close the topic thanks.',
#    'Do you think Cryptocurrencies is already invading our Planet?',
#    'The fake Satoshi Craig Wright in action',
#    'If Bitcoin is the new Gold it will be worth...',
#    'Interesting Stories, Insights, Metaphors, Quotes, etc.',
#    'Telegram Short-Long term Trade signals with Technical Analysis']},
#  '2017-11-16': {'teme_list': ['exchange websites for cryptocurrency',
#    'Vietnam Bans Bitcoin as Payment',
#    'Questions about Bitcoin Core and Bandwidth on Local Network',
#    'Bitcoin Robbery in Istanbul',
#    'Blockchain, Democracy and Voting',
#    'What is the best wallet to use for offline storage of cryptos?',
#    'Satoshi was a Zen Buddhist U can see that in his Emails BITCOIN is Patience',
#    'Is that a reality " Bitcoin is a bubble waiting to burst"??? ',
#    'Rich Irony that "Traders" Pay High Fee\'s that Go to "MINERS" LOVE BTC',
#    'Why HIGH Fees? Tax Crypto-Trading of BTC out of Existance - BTC is a BANK',
#    'Concerns raised over North Korean cryptocurrency hackers',
#    'Sim Swapped...',
#    'Is it fucking Christmas!!! ',
#    'Any particular reason why the fees on transactions are so high right now?',
#    'why not using btc/eth instead of eth/btc',
#    "Satoshi Invented BITCOIN to be a BANK, not a 'PAYPAL' for buying Coffee",
#    'Is Bitcoin the biggest wealth distribution system ever?',
#    'BTC Rollercoaster Price',
#    'BITCOIN Electricity Problems in CHINA - BULLSHIT Story from Team-BCH',
#    'A Little Review: Three Earth-Shaking Cryptocurrency Events ',
#    'okex a bug, resulting in a Bitcoin for a villa',
#    'BTC double spend',
#    "Where to find Satoshi's original whitepaper?",
#    'BITCOIN SERVER IS TURNED OFF',
#    "Japan's virtual currency currencies have risen several times,",
#    'Preparing new BTC attack?']},
#  '2017-11-17': {'teme_list': ['Why Bitcoin Cash will NEVER be bitcoin',
#    'Crypto Warriors Club ~ The Best Upcoming PUMPS!',
#    'Bitcoin bringing new excitement to the property market',
#    'Is Segwit2X fork cancelled or it will happen',
#    'is bitcoin cash, the next Bitcoin 2.0???',
#    'UNAUTHORIZED TRANSACTION - INPUTS PLEASE',
#    'Bitpico  , segwit2X going ahead as Planned!!!',
#    'Bitcoin vs BitCoinCash: From Flippening to Floppening? ',
#    'Other way to transfer or withdraw your BTC',
#    'Created an iOS app to track the upcoming bitcoin forks',
#    'HOT Jamie Dimon Breaks One-Day Silence to Call Bitcoin Investors Stupid HOT',
#    'Payment solution Square backs Bitcoin',
#    'Fujitsu Japanese IT firm unveils new payment tech for crypto trading',
#    'If $1 Million BTC is the target, then we have at least 12,567% or 125x to go',
#    "Is this one of BTC's Market Manipulative tactics?",
#    'Why Craig Steven Wright claimed he is Satoshi Nakamoto?',
#    'Stupid question ',
#    'Did Segwit2x happen (as per Coinbase email)? How to get Bitcoin2x?',
#    'BTC ....The savior!!!!!!! really? ',
#    'How to easily bill customers (as like as cc billing) via Bitcoin on our paysite?',
#    'Do you think Segwit2x will come alive?',
#    '21.000.000 Bitcoin!',
#    'Trader Tom Luongo explains why Bitcoin is like Gold',
#    'Can this happen to Bitcoin?',
#    'Please be careful while using different wallet Services',
#    'Bitcoin Transaction Stuck!',
#    'Square payment app now has Bitcoin! Huge news!',
#    'Over 20 Banks Join Singapore-Hong Kong Blockchain Trade Network',
#    'Announcing Coinbase Custody: A Digital Currency Custodian For Institutions',
#    'Morgan Stanley CEO Gorman plays down Bitcoin growth',
#    'Bitcoin segwit2x continue?',
#    'Uphold freezes account due to 165 BTC deposit',
#    'Five Countries Where Bitcoin is Illegal',
#    'Will hedge funds short or long Bitcoin immidiately after CME starts BTC futures?',
#    'Documentary on Bitcoin - Summary Thread',
#    'Is there any research about the legalization of bitcoin?',
#    'CME regulating BTC in 4days - BTC will skyrocket?',
#    'UBS says it will not make bitcoin a portfolio allocation']},
#  '2017-11-19': {'teme_list': ['segwit2x Hard Fork happen now ? realy ????',
#    'Bitcoin Businesses Suffers In Hong Kong As Local Bank Froze Account',
#    'Why Bitcoin so volatile?',
#    'In the Netherlands',
#    'Bitcoin Forks',
# ...
#    'What will happen after 21 million bitcoin have been mined? ',
#    "Isn't speculation and volatility a problem for Bitcoin?",
#    'What is the best cryptocurrency to invest in right now?']},
#  '2021-10-06': {'teme_list': ['Get a $0.20 per gallon discount on petrol when paying with Bitcoin.',
#    'Bitcoin Vs Future?',
#    'How has Bitcoin Changed your life?',
#    'How to properly use a Mixer?']},
#  '2021-10-07': {'teme_list': ['There is something wrong with cryptocurrencies? ',
#    'SEC Chair Dodges Question About Regulatory Status of Bitcoin']},
#  '2021-10-08': {'teme_list': ['China Quitting Bitcoin Mining Is Very Positive in Long Term',
#    'BTC is Going to "DEAD....!" Need Discussion.....',
#    'LAST CALL for voting MTGOX rehabilitation plan: deadline on October 8th 2021',
#    'Is Bakkt the Future of Bitcoin and cryptoworld?',
#    'United state 🇺🇸  take the lead in global Bitcoin adoption 2021',
#    '12 years today since the first known price was set for BTC']},
#  '2021-10-09': {'teme_list': ['Bangladesh may be approve bitcoin very soon according to ICT MINISTER ',
#    'Bitcoin ETF approved for Largest holders in US',
#    'Bitcoin transactions is so expensive']},
#  '2021-10-10': {'teme_list': ['TBD',
#    'US Infrastructure Bill 2021 and Bitcoin',
#    'What is the biggest threat to Bitcoin?',
#    'Bitcoin issued',
#    'Bitcoin the hedge against inflation',
#    'The top 3 the best anonymous wallets and practices to anonimize Bitcoin in 2021']},
#  '2021-10-11': {'teme_list': ['Why I like to learn and use bitcoin',
#    "new to bitcoin, don't know how to use",
#    'Dollar supporters destroy Bitcoin ATM in El Salvador',
#    'Why some millionaires hate Bitcoin?',
#    'Why do many mainstream economists always oppose Bitcoin?',
#    'Never pay capital gains tax',
#    'New Blockchain and Some Ideas',
#    'Is Satoshi about to show up?',
#    'Legalization. In Ukraine and now Laos',
#    'Why hoard Bitcoin?']},
#  '2021-10-12': {'teme_list': ['is it possible to just copy and paste the bitcoin code?',
#    'Bitmain Confirms Halting Its Shipment of Antminers to Chinese Customers，why',
#    'On-Chain Metrics Paint a Bullish Outlook',
#    'iancloman+bitaddress.org and passphrase as a privatekey for coldstorage ?',
#    'Mining Reward Block 2,100,000+',
#    'Podcast : Bitcoin']},
#  '2021-10-13': {'teme_list': ['🛠️ Bitcoin LightningATM',
#    'The misconception when buying/investing in Bitcoin',
#    'Bitcoin Related Question Comes In a Admission Test Exam',
#    'I predict stricter regulations for bitcoin and the cryptospace for 2021-2024',
#    'China issue a nationwide ban on cryptocurrency mining, ',
#    'Iranian Bitcoin Mining Ban Lifted after four Months',
#    'Bitcoin trades at $56,000 as daily settlement value hits $31 billion',
#    'How 63 bit puzzle a other low puzzles were solved?']},
#  '2021-10-14': {'teme_list': ['Ark Invest Reveals New Data on Bitcoin Asset Classification',
#    'Bitcoin mentioned in Ted Lasso finale',
#    'Some Interesting Facts About BITCOIN']},
#  '2021-10-15': {'teme_list': ['satoshi symbol']},
#  '2021-10-16': {'teme_list': ['Is Bitcoin truly a safe-haven asset?',
#    'The HODL to 100K movement']},
#  '2021-10-17': {'teme_list': ['[Competition] Private Key for 1BTC wallet hidden in a music clip',
#    'Venezuela Airport accepting Bitcoin ',
#    'Bitcoin Without ETF']},
#  '2021-10-18': {'teme_list': ['Transaction says received but I did not receive it please help',
#    'I am new to Bitcoin and have been using Coinbase only.']},
#  '2021-10-19': {'teme_list': ['Estonia on a road to possibly revoke most crypto licenses issued in the country',
#    'Doctor Doom Nouriel Roubini now NOT anti-Bitcoin']},
#  '2021-10-20': {'teme_list': ["Let's Say Bitcoin is scam ",
#    '6000 coinbase clients hacked',
#    'What problems face Bitcoin?',
#    'First Bitcoin Futures ETF in The US Starts Trading',
#    "[Graph] Average return of Bitcoin, you can't lose money stacking continuously",
#    'The Great Thing is about Bitcoin',
#    'Bitcoin in Movies.',
#    'Any Office to rent that accepts Bitcoin? (MORE DETAILS IN THREAD)']},
#  '2021-10-21': {'teme_list': ['Would you quit Bitcoin if a shitcoin like Ethereum surpassed it?',
#    'First Bitcoin Futures ETF Trades Nearly $1 Billion in One Day',
#    '***BREAKING *** Bitcoin ETF is approved',
#    'Off chain transactions (trigger warning)',
#    'Why is telling people you\'re into stocks "cool" but crypto is a big secret? ']},
#  '2021-10-22': {'teme_list': ['[STOP] My Challenge with small investment in bitcoin',
#    'Russia took third place in the world in bitcoin mining',
#    'Why would anyone buy an ETF that yielded BTC minus 12% per year?',
#    'Buying BTC with Credit Cards (not Debit Cards)',
#    'Binance.US takes price 87% down ']},
#  '2021-10-23': {'teme_list': ['Bitcoin flash crashes to $8200 at Binance.us',
#    "Tether and BTC's current price"]},
#  '2021-10-24': {'teme_list': ['Bitcoin > Gold',
#    'One of the best coin Bitcoin']},
#  '2021-10-25': {'teme_list': ['Bitcoin lightning OPEN/CLOSE transactions',
#    'All crypto declared illegal in China!!!!!!!!!!!!!',
#    'Russia blocks localbitcoins']},
#  '2021-10-26': {'teme_list': ['Who owns bitcoin foundation?']},
#  '2021-10-27': {'teme_list': ['After a few months of China crackdown on mining. Check it out!',
#    'US Bitcoin Mining Council Survey Confirms Industry Powered By 57.7% Renewables',
#    'US SEC Delays Decision on Direxion Bitcoin ETF Until September',
#    'Bitcoin Price vs Iphone Price at launch ']},
#  '2021-10-28': {'teme_list': ['We enter a new era of heavy regulations',
#    "What are some interesting ways you've introduced bitcoin to your friends?",
#    'The risks of using Bitcoin',
#    'Need some help!! ',
#    'What the government expect from bitcoin legality?']},
#  '2021-10-29': {'teme_list': ['SNL had a skit where they said the Devil invented Bitcoin',
#    'Why do many people call Bitcoin "digital gold"?',
#    'Advice: 1 BTC',
#    'Mastercard and Bakkt  Verifone and BitPay ',
#    'TV Commercials & How they attracting more clients in crypto industry.']},
#  '2021-10-30': {'teme_list': ['FDIC Allows Banks to Own Bitcoin',
#    'Wont the amount of bitcoin in circulation vanish? ',
#    'Help me understand BTC pricing']},
#  '2021-10-31': {'teme_list': ['Dust payments to my wallet what is he trying to do?',
#    'ESG Criteria: Concerns',
#    'How Twitter can make impact in the BTC world?',
#    'Alternative to bip39 : memorizing your seed with the PEG system',
#    'The higher BTC goes, the bigger the risk/reward ratio and the less buyers enter',
#    "Bitcoin puzzle (3,350.00 BTC's )"]},
#  '2021-11-01': {'teme_list': ['Large SALES Exchange or OTC how do you cashout 500-1million+?',
#    'Bitcoin not a seek and hide for fraudulency']},
#  '2021-11-02': {'teme_list': ['Banks either adapt or face death']},
#  '2021-11-03': {'teme_list': ['The president of El Salvador just bout 420 BTC!',
#    'Possible to get BTC wallet with 2 different changable passwords?',
#    'China Ban and the mining exodus',
#    "Wrong BTC Adress, copied from Binance's Dashboard"]},
#  '2021-11-04': {'teme_list': ["Russia doesn't wants its citizens earning with cryptos ",
#    'Mining vs Holding',
#    'Verifying my (old) zero balance wallet address for blockchain research etc.,',
#    'Happy 13th Anniversary Bitcoin Whitepaper']},
#  '2021-11-05': {'teme_list': ['Walmart Sells Bitcoin',
#    'Selling items for 0.0004 Bitcoin.',
#    'Bitcoin and Stablecoin Regulation',
#    "Bitcoin's Fungibility Issue",
#    'Flood attack 0.00000001 BC',
#    'Bitcoin Politicians in US',
#    'Not your vault, not your money. Why some nation-states will HODL Bitcoin.',
#    'Blockchain agents ']},
#  '2021-11-06': {'teme_list': ["What's so \x93convincing\x94 about Craig Wright?",
#    'Bitcoin and the Power/Energy/Electricity Grid concerns & questions',
#    'Bitcoin Testnet Converter to Bitcoin Livenet',
#    'Intrinsic value of Bitcoin and Gold',
#    'Reason for bitcon flash drop. ',
#    "Andreas' current use of BTC",
#    'Ira Kleiman is obviously lying in court - Team up with CSW to create evidence?',
#    'I have 500 lost Bitcoin - need help']},
#  '2021-11-07': {'teme_list': ['Treasury bonds and bitcoin',
#    'Keys.lol and similar sites that searches for all private keys',
#    'Daily Reminder: Watch Out for $5 Wrench Attacks',
#    '$875 million profited by Cash app this second quarter, amidst the pandemic']},
#  '2021-11-08': {'teme_list': ['Cryptocurrency must adapt  in schools/colleges curriculum ',
#    '5 Bitcoin Script quirks that every Blockchain developer should know',
#    "Doesn't it teach, BTC Price will never go down if we won't force it to go down?"]},
#  '2021-11-09': {'teme_list': ['Privacy vs. anonymity',
#    'Jamie Dimon asks, \x93How do we know Bitcoin supply ends in 21 million\x94?',
#    'Bitcoin Hedging Platforms and Strategy']},
#  '2021-11-10': {'teme_list': ['Good news through Mastercard. ',
#    'Google/bing Ads with Bitcoin ?',
#    'Why did you miss Bitcoin?',
#    'Sergey Nazarov has created a monster & it is dragging all of crypto down with it']},
#  '2021-11-11': {'teme_list': ['Fiat On-Ramps',
#    'No, China is not planning on unbanning bitcoin mining',
#    'How can we accelerate the mass adoption of crypto?',
#    'How Bitcoin can help Local Communities',
#    'Apple CEO: Tim Cook already interested in Bitcoin',
#    'Going public saying you own Bitcoin is not safe anymore',
#    'Bitcoin circulation increases',
#    'bitcoin investment trust']},
#  '2021-11-12': {'teme_list': ['Bitcoin TapRoot Update?',
#    'MY BLOCKCHAIN WALLET WAS STOLEN 0.39070099 BTC !!!',
#    'Taproot will follow segwit pump',
#    'China is thinking about unbanning bitcoin mining after price rise',
#    'Bitcoin ATM stolen in a liquior store',
#    'From pizza to bitcoins - to factory to bitcoins',
#    'How the validation after the mining can detect a fraudolent node behaviour']},
#  '2021-11-13': {'teme_list': ['Is it possible, that Satoshi used precalculated addresses and not random addr.']},
#  '2021-11-14': {'teme_list': ['Do We Embrace Sidechains?',
#    'Sweden proposed to ban mining in the European Union']},
#  '2021-11-15': {'teme_list': ['Today I helped 2 non-crypto people invest in bitcoin',
#    'AMC Theatres Debuts Bitcoin Payments',
#    'Why Are More Whales Moving Their BTC?']},
#  '2021-11-16': {'teme_list': ['Is bitcoin an asset or a currency?',
#    'Best thing you bought with Bitcoin?',
#    'Kids into Cryptocurrency Mining']},
#  '2021-11-17': {'teme_list': ['Hi coiners, what would you suggest bout bitcoin amelioration?',
#    'The US President New Restrictions on Crypto Businesses',
#    'USA Bitcoin mining, development, running nodes, transfer >$10K now felonies']},
#  '2021-11-18': {'teme_list': ['What are implications of total satellite destruction on Bitcoin?',
#    'El Salvador to mine bitcoin using Volcanic energy',
#    'BlockFi/Celsius vs Cold Wallet']},
#  '2021-11-19': {'teme_list': ['Tesla make 1 billion profits from it Bitcoin holding ',
#    "New York's Mayor-Elect to Take His First Paychecks in Bitcoin",
#    'El salvadore and btc ',
#    'Will Cryptocurrency be a Global Currency in the Future?',
#    'Do you believe BTC can be attacked?',
#    "What's your strategy to carry on making money when Bitcoin turns bearish",
#    'This Baseball Team Now Pays Players in Bitcoin',
#    'Staples Center to be renamed Crypto.com Arena on Christmas Day!!']},
#  '2021-11-20': {'teme_list': ['They are starting to get really worried!',
#    'Mining and energy ',
#    'Happy Satoshi Nakamoto Day',
#    'Mixer Detection in 2021']},
#  '2021-11-21': {'teme_list': ['The Future',
#    'My first time using a Bitcoin ATM',
#    'What Bitcoin stands to gain when the government prints more currencies',
#    'Verified Information - Missed Opportunities',
#    'Bitcoin brings us true freedom of thought',
#    "Crypto Wallet's and their compliancy with law enforcement"]},
#  '2021-11-22': {'teme_list': ['What has bitcoin done for you?',
#    'El Salvador to Create \x91Bitcoin City,\x92',
#    'Bitcoin City Rising in El Salvador']},
#  '2021-11-23': {'teme_list': ['Some Walk-In Foreign Exchange Places Offer BTC']},
#  '2021-11-24': {'teme_list': ['5 Key words (short sentence) to explain BTC',
#    'Bad news for cryptocurrency enthusiasts in India',
#    'Brazilian Congressman proposes Crypto Payment for workers',
#    'El Salvador\x92s Bitcoin city - So what are your thoughts about this one? ',
#    'Crypto Wash Trading - Concerns?',
#    'What if the US Govt. buys circulating Bitcoin Supply and $ is backed by $BTC ?',
#    'Is Tax holding back bitcoin from going to the Moon']},
#  '2021-11-25': {'teme_list': ['luck or hack?',
#    'The War Between Cryptocurrencies and Central Bank Digital Currencies (CBDCs)']},
#  '2021-11-26': {'teme_list': ['Apple CEO Tim Cook invests on Crypto',
#    'BTCD (not bitcoind) initial block download - ibd - will take two weeks',
#    'Uruguayan Lawmaker Proposes Bill to Treat Crypto as Legal Tender']},
#  '2021-11-28': {'teme_list': ["does this have something to do with bitcoin's current decline... ",
#    'BitCoin Scamming Business is Booming!',
#    "What's up with the flaunting of irreversibility?"]},
#  '2021-11-29': {'teme_list': ['How reasonable is it to invest in Bitcoin in the current situation?',
#    'No Ban. Crypto will probably get Regulated in India.',
#    '#buythedip is trending all around']},
#  '2021-11-30': {'teme_list': ["Saw my 1st 'hybrid' Bitcoin ATM this morning.",
#    'Bitcoin Citadels Poll ',
#    '41% of people globally say they trust Bitcoin over local currencies']},
#  '2021-12-01': {'teme_list': ['Do you want to see Bitcoin legal in your country? ',
#    "Bitcoin's price, and our mental health.",
#    'The paradox of Bitcoin adoption',
#    'Newb question about torshops mechanics',
#    'JP Morgan believes Bitcoin is Overpriced']},
#  '2021-12-02': {'teme_list': ['are crypto owners naturally paranoid?',
#    "Why Bitcoin seen as 'Risk On' Asset instead of Gold's 'Risk Off' Status?",
#    "Satoshi Nakamoto's Wealth",
#    'Decrypt .key old multibit wallet']},
#  '2021-12-03': {'teme_list': ['How can people in Afganistan use crypto?',
#    'Do you spend your Bitcoin?',
#    'Microstrategy Buy more Bitcoin ',
#    'Bitcoin canada ETF approved spot etf explained ',
#    'Right now Bitboy Ben vs saylor and pomp ',
#    'Micheal saylor clown ']},
#  '2021-12-04': {'teme_list': ['Debunking a few crypto myths - governments that allegedly own Bitcoin.',
#    'Btc porn getting more funny as it gets ',
#    'Bitcoin logo',
#    'How to know the derivation paths used by hardware wallets? ',
#    'Was Bitcoin talked about at your Thanksgiving celebration?',
#    'I only have 0.001 Bitcoin is that okay?']},
#  '2021-12-05': {'teme_list': ['Still worth to invest Bitcoin?',
#    'Bitcoin Adoption Report Card - Year 12',
#    'When Religion and Finance [Bitcoin] Overlap and Clash',
#    'Crypto Community is Lit ',
#    'bitcoin scam, email name is Merci Panasyuk <ofbtbartondh@outlook.com>',
#    'Home Economics TV show mentions payment in \x93crypto\x94']},
#  '2021-12-06': {'teme_list': ['Why the Bitcoin logo is Orange ?',
#    '¿what is the contribution to the society of the idea behind bitcoin?',
#    'What is the highest non-service wallet you ever dealt with?',
#    'Bitcoin as Education Insurance',
#    "I'M back! My next move with Bitcoin",
#    'Factors affecting bitcoin business']},
#  '2021-12-07': {'teme_list': ['Bitcoin Falling due to FUD (Fear Uncertainty Doubt) ?',
#    'Safety ',
#    'No one can continue ignoring Bitcoin',
#    'Am I Doing My Students a Disservice? ',
#    'Nearly 90% of all Bitcoin will have been mined in about one week.',
#    'The relationship between Bitcoin and human civilization',
#    'Need a wallet finder for exchanges',
#    'People say its ok to lose in crypto and btc but here is important message to all',
#    'Why people gone crazy about satoshi ']},
#  '2021-12-08': {'teme_list': ['Is there a chance for Bitcoin Recovery?',
#    'When is the Bitcoin symbol going to be added to the keyboard?',
#    'What would you consider living on crypto?',
#    'Bitcoin as Means of Donation ',
#    "How to improve a bitcoin site's Google ranking",
#    'Fidelity entering the crypto world',
#    'Bitcoin platform',
#    'Banks and Bitcoin- The needed change']},
#  ...}

# %% [markdown]
# ### Uvoz bilblioteke Transformers
# * modul `pipeline` omogućuje upotrebu osnovnog deep learning modela za analizu teksta
# * deep learning model `sentiment-analysis` analizira tekst i vraća rezulte u brojevnom obliku
# * ključevi dict-a su `label` koji za vrijednost ima polaritet (Positive/Negative) i score koji označuje rezultat od 0-1 i

# %%
from transformers import pipeline
sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# C:\Users\Loren\anaconda3\lib\site-packages\huggingface_hub\file_download.py:133: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Loren\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %% [markdown]
# #### Izrada funkcije za analizu komentara
# * Ako je uneseni tekst unutar modela pozitvno orijetitan poput "like", "great", "rise", `label` će biti `POSITIVE`
# * Tekst poput "hate", "collapse", "fallout" će vratit vrijednost label ključa `NEGATIVE`
# * Na osnovu tih vrijednosti se izrađuje funkcija, koja ako je label NEGATIVE vraća negativnu vrijednost rezultata
# * analiziranje teksta staje na 100 znakova unesenog teksta (`tekst[:100]`) kako bi se funkcija izvršila u što kraćem roku, što ubrzava izvođenje daljnjeg programskog koda
# * index [0] se postavlja jer je sentiment_pipeline vraća dictonary unutar liste, 0 je prvi element liste

# %%
def analiza_sent(tekst):
    tema=sent_pipeline(tekst[:100])[0]
    rezultat=tema["score"]
    polaritet=tema["label"]
    if polaritet=="NEGATIVE":
        rezultat*=-1
    return rezultat

# %%
rez_transf={}
for dat in teme:
    lista_tema = teme[dat]["teme_list"]
    rez_transf[dat]=dict(broj_tema=len(lista_tema), rezultati=list())
    for tema in lista_tema:
        rez_transf[dat]["rezultati"].append(analiza_sent(str(tema)))

# %%
# funkcije za odvajanje pozitvinih od negativnih komentara
def pozitivni(lista):
    return [br for br in lista if br >= 0]

def negativni(lista):
    return [br for br in lista if br<0]

# %%
end_transf={}

for k in rez_transf:
    rez=rez_transf[k]["rezultati"]
    end_transf[k]=dict(broj_tema=rez_transf[k]["broj_tema"],avg_rezultata=float,
                       posto_poz=float,posto_neg=float)
    end_k=end_transf[k]
    end_k["avg_rezultata"]=sum(rez)/len(rez) 
    end_k["posto_poz"]=len(pozitivni(rez))/len(rez)
    end_k["posto_neg"]=len(negativni(rez))/len(rez)

# %%
len(end_transf)
# Out:
# 1410

# %% [markdown]
# ## Prebacivanje rezultata u pandas df

# %%
# pretvarnje end_transf dictionary-a u tablicu
df_transf=pd.DataFrame.from_dict(end_transf,orient="index")

# %%
# Postavljanje datetime index-a
df_transf.index=pd.to_datetime(df_transf.index)

# %%
df_transf
# Out:
#             broj_tema  avg_rezultata  posto_poz  posto_neg
# 2017-10-11         13      -0.534152   0.230769   0.769231
# 2017-10-12         27      -0.539031   0.222222   0.777778
# 2017-10-16         25      -0.622153   0.160000   0.840000
# 2017-10-17         15      -0.626765   0.200000   0.800000
# 2017-10-18          1      -0.998893   0.000000   1.000000
# ...               ...            ...        ...        ...
# 2023-01-19          4      -0.009539   0.500000   0.500000
# 2023-01-20          4      -0.487088   0.250000   0.750000
# 2023-01-21          2       0.002150   0.500000   0.500000
# 2023-01-23          6       0.323947   0.666667   0.333333
# 2023-01-24          1      -0.994406   0.000000   1.000000
#
# [1410 rows x 4 columns]

# %%
datumi=pd.date_range(start="10-09-2017",end="01-23-2023")

# %%
# definiranje varijble koja će postati novi index
# postavljnje početnog i završnog datuma
datumi=pd.date_range(start=last_year_date,end=today_date)

# %%
# reindeksirenje i ispunjavanje nepostojećih datuma s vrijednostima 0
df_reindex=df_transf.reindex(datumi,fill_value=0)

# %%
df_reindex
# Out:
# 367

# %%
# upotreba rolling funkcije za pronalazak srednje vrijednosti posljednjih 7 dana
rolling_transf=df_reindex.rolling(7).mean()

# %%
# izbacivanje NaN vrijednosti koje su kreirane rolling funkcijom
rolling_transf=rolling_transf.dropna()

# %%
# Prebacivanje konačne tablice u .csv dokument
rolling_transf.to_csv("Transf_roll7_new.csv")

# %% [markdown]
# ### Upotreba funkcije rolling
# * rolling omogućuje izračun srednje vrijednosti podataka u posljednjih 7 dana srednja vrijednost od 1. do 7. reda zapisan je u 7. red, 8 red ima zapisanu srednju vrijednost od 2. do 8. reda i tako do kraj tablice
# * prvih 7 redova ima NaN vrijednosti je nemaju prethodnih podataka za izračun pa ih je potrebno ukloniti
